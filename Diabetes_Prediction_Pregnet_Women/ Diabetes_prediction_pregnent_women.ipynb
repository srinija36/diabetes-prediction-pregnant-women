# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
df = pd.read_excel("data/diabetes_pregnant_1000_records.xlsx")
df.head()
# Out:
#    Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0            6   94.544379      70.120280      44.653415   86.284348
# 1            3   91.912649      63.488812      30.397803  129.288558
# 2           12  129.995199      60.770617      15.422918  137.314897
# 3           14  112.262935      42.737369      31.499616   22.290931
# 4           10   60.000000      57.080069      35.594805   45.638898
#
#          BMI  Age  Outcome
# 0  23.543743   39        0
# 1  31.294917   25        0
# 2  28.919243   43        0
# 3  33.194468   45        0
# 4  41.575985   22        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pregnancies    1000 non-null   int64
#  1   Glucose        1000 non-null   float64
#  2   BloodPressure  1000 non-null   float64
#  3   SkinThickness  1000 non-null   float64
#  4   Insulin        1000 non-null   float64
#  5   BMI            1000 non-null   float64
#  6   Age            1000 non-null   int64
#  7   Outcome        1000 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 62.6 KB

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.isnull().sum()
# Out:
# Pregnancies      0
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# Age              0
# Outcome          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'Age', 'Outcome'],
#       dtype='object')

# %%
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# %%
X.head()
# Out:
#    Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0            6   94.544379      70.120280      44.653415   86.284348
# 1            3   91.912649      63.488812      30.397803  129.288558
# 2           12  129.995199      60.770617      15.422918  137.314897
# 3           14  112.262935      42.737369      31.499616   22.290931
# 4           10   60.000000      57.080069      35.594805   45.638898
#
#          BMI  Age
# 0  23.543743   39
# 1  31.294917   25
# 2  28.919243   43
# 3  33.194468   45
# 4  41.575985   22

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Outcome, dtype: int64

# %%
y.tail()
# Out:
# 995    0
# 996    1
# 997    0
# 998    0
# 999    0
# Name: Outcome, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (800, 7)

# %%
X_test.shape
# Out:
# (200, 7)

# %%
y_train.shape
# Out:
# (800,)

# %%
y_test.shape
# Out:
# (200,)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = SVC(kernel='rbf', C=1, gamma='scale')
model.fit(X_train, y_train)
# Out:
# SVC(C=1)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.88
#
# Confusion Matrix:
#  [[141   8]
#  [ 16  35]]

# %%
def predict_new(preg, glu, bp, skin, ins, bmi, age):
    point = np.array([[preg, glu, bp, skin, ins, bmi, age]])
    point_scaled = scaler.transform(point)
    result = model.predict(point_scaled)
    return "Diabetic" if result[0] == 1 else "Not Diabetic"

# %%
predict_new(4, 165, 82, 35, 130, 36.5, 40)
# Out:
# C:\Users\ganju\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 'Diabetic'

# %%
predict_new(2, 130, 70, 28, 80, 30.0, 29)
# Out:
# C:\Users\ganju\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 'Not Diabetic'

# %%
predict_new(1, 92, 60, 22, 65, 24.8, 22)
# Out:
# C:\Users\ganju\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 'Not Diabetic'
